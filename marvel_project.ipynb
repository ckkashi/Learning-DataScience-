# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
marvel_dataset = pd.read_csv('charcters_stats.csv')

# %%
marvel_dataset.head()
# Out:
#           Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0      3-D Man      good            50        31     43          32     25
# 1       A-Bomb      good            38       100     17          80     17
# 2   Abe Sapien      good            88        14     35          42     35
# 3     Abin Sur      good            50        90     53          64     84
# 4  Abomination       bad            63        80     53          90     55
#
#    Combat  Total
# 0      52    233
# 1      64    316
# 2      85    299
# 3      65    406
# 4      95    436

# %%
marvel_dataset.shape
# Out:
# (611, 9)

# %%
marvel_dataset.columns
# Out:
# Index(['Name', 'Alignment', 'Intelligence', 'Strength', 'Speed', 'Durability',
#        'Power', 'Combat', 'Total'],
#       dtype='object')

# %%
marvel_dataset['Alignment'].value_counts()
# Out:
# good       432
# bad        165
# neutral     11
# Name: Alignment, dtype: int64

# %%
good_alignment = marvel_dataset[marvel_dataset['Alignment'] == 'good']

# %%
good_alignment.sort_values(by='Power',ascending=False).head(n=10)
# Out:
#               Name Alignment  Intelligence  Strength  Speed  Durability  \
# 609        Zatanna      good            75        10     23          28
# 546           Thor      good            69       100     92         100
# 511          Spawn      good            75        60     50          90
# 69   Beta Ray Bill      good            63        80     35          95
# 70        Beyonder      good            88       100     23         100
# 499  Silver Surfer      good            63       100     84         101
# 487    Shadow King      good            75        12     27         100
# 85      Black Bolt      good            75        67    100          84
# 435    Plastic Man      good            50        63     23         100
# 433        Phoenix      good           100        80     67         100
#
#      Power  Combat  Total
# 609    100      56    292
# 546    100      85    546
# 511    100      95    470
# 69     100      84    457
# 70     100      56    467
# ...

# %%
marvel_dataset.sort_values(by='Power',ascending=False)
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 372         Mephisto       bad            88        85     35          95
# 418             Nova      good            38        60    100         100
# 69     Beta Ray Bill      good            63        80     35          95
# 383     Miss Martian      good            63        85     58         100
# 386  Mister Mxyzptlk       bad           113        10     12          14
# ..               ...       ...           ...       ...    ...         ...
# 274          Hawkman      good             1         1      1           1
# 104       Blizzard I       bad             1         1      1           1
# 109      Bloodwraith       bad             1         1      1           1
# 264         Guardian      good             1         1      1           1
# 148          Cerebra      good             1         1      1           1
#
#      Power  Combat  Total
# 372    100      42    445
# ...

# %%
bad_100 = marvel_dataset[(marvel_dataset['Alignment'] == 'bad') & (marvel_dataset['Power'] == 100)]

# %%
bad_100.shape
# Out:
# (20, 9)

# %%
bad_100.sort_values(by='Speed',ascending=False)
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 16             Amazo       bad            75       100    100         100
# 535   Superboy-Prime       bad            94       100    100         100
# 11        Air-Walker       bad            50        85    100          85
# 171  Cyborg Superman       bad            75        93     92         100
# 5            Abraxas       bad            88       100     83          99
# 203         Dormammu       bad            88        95     83         100
# 218    Fallen One II       bad            88        85     83         100
# 356            Magus       bad            88       100     70          99
# 201         Doomsday       bad            88        80     67         120
# 501         Sinestro       bad            75        80     53          64
# 422        Onslaught       bad            88        85     47         100
# 564           Ultron       bad            88        83     42         100
# ...

# %%
alignments = marvel_dataset['Alignment'].value_counts()

# %%
plt.figure(figsize=(5,5))
plt.bar(alignments.keys(),alignments.values,color='g')
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.hist(marvel_dataset['Speed'])
plt.show()
